# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil-xyz/Agentic-AI/blob/main/Agentic_AI_GROQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install phidata
# Out:
# Collecting phidata
#   Downloading phidata-2.7.10-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.11/dist-packages (from phidata) (0.16)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.11/dist-packages (from phidata) (3.1.44)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from phidata) (2.10.6)
# Collecting pydantic-settings (from phidata)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting python-dotenv (from phidata)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from phidata) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from phidata) (13.9.4)
# Collecting tomli (from phidata)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from phidata) (0.15.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from phidata) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->phidata) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->phidata) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->phidata) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->phidata) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->phidata) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->phidata) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->phidata) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->phidata) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer->phidata) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->phidata) (1.3.1)
# Downloading phidata-2.7.10-py3-none-any.whl (716 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.9/716.9 kB 11.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: tomli, python-dotenv, pydantic-settings, phidata
# Successfully installed phidata-2.7.10 pydantic-settings-2.8.1 python-dotenv-1.0.1 tomli-2.2.1

# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.18.0

# %%
from phi.agent import Agent
from phi.model.groq import Groq
from phi.tools.yfinance import YFinanceTools

# %%
from google.colab import userdata
groq_api_key = userdata.get('GROQ_API_KEY')

# %%
agent = Agent(
    model = Groq(id = "llama-3.3-70b-versatile", api_key=groq_api_key),
    tools = [YFinanceTools(stock_price=True, analyst_recommendations=True, stock_fundamentals=True)],
    show_tool_calls = True,
    markdown = True,
    instructions = ["use tables to display data"],
    debug_mode = True
)
# Out:
# DEBUG    Debug logs enabled

# %%
agent.print_response("summarize and compare analyst recommandations and fundamentals for TESLA and NVDA")
# Out:
# DEBUG    *********** Agent Run Start: 187a4a79-d7e9-4eba-afd8-e50d8935b0d8 ***********
# DEBUG    Function get_current_stock_price from yfinance_tools added to model.
# DEBUG    Function get_stock_fundamentals from yfinance_tools added to model.
# DEBUG    Function get_analyst_recommendations from yfinance_tools added to model.
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - use tables to display data
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    summarize and compare analyst recommandations and fundamentals for TESLA and NVDA
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
#              "id": "call_z6qp",
#              "function": {
#                "arguments": "{\"symbol\": \"TSLA\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_fjja",
#              "function": {
#                "arguments": "{\"symbol\": \"NVDA\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_dsp3",
#              "function": {
#                "arguments": "{\"symbol\": \"TSLA\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_x5c2",
#              "function": {
#                "arguments": "{\"symbol\": \"NVDA\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   2.0090s
# DEBUG    * Tokens per second:           205.0723 tokens/s
# DEBUG    * Input tokens:                438
# DEBUG    * Output tokens:               412
# DEBUG    * Total tokens:                850
# DEBUG    * Completion time:             1.4982s
# DEBUG    * Prompt time:                 0.0199s
# DEBUG    * Queue time:                  0.2781s
# DEBUG    * Total time:                  1.5181s
# DEBUG    **************** METRICS END ******************
# DEBUG    Getting function get_analyst_recommendations
# DEBUG    Getting function get_analyst_recommendations
# DEBUG    Getting function get_stock_fundamentals
# DEBUG    Getting function get_stock_fundamentals
# DEBUG    Running: get_analyst_recommendations(symbol=TSLA)
# DEBUG    Running: get_analyst_recommendations(symbol=NVDA)
# DEBUG    Running: get_stock_fundamentals(symbol=TSLA)
# DEBUG    Running: get_stock_fundamentals(symbol=NVDA)
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - use tables to display data
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    summarize and compare analyst recommandations and fundamentals for TESLA and NVDA
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
#              "id": "call_z6qp",
#              "function": {
#                "arguments": "{\"symbol\": \"TSLA\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_fjja",
#              "function": {
#                "arguments": "{\"symbol\": \"NVDA\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_dsp3",
#              "function": {
#                "arguments": "{\"symbol\": \"TSLA\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            },
#            {
#              "id": "call_x5c2",
#              "function": {
#                "arguments": "{\"symbol\": \"NVDA\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: call_z6qp
# DEBUG    {"0":{"period":"0m","strongBuy":7,"buy":13,"hold":15,"sell":9,"strongSell":3},"1":{"period"
#          :"-1m","strongBuy":7,"buy":13,"hold":15,"sell":9,"strongSell":3},"2":{"period":"-2m","stron
#          gBuy":7,"buy":13,"hold":15,"sell":8,"strongSell":4},"3":{"period":"-3m","strongBuy":7,"buy"
#          :13,"hold":15,"sell":8,"strongSell":5}}
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: call_fjja
# DEBUG    {"0":{"period":"0m","strongBuy":11,"buy":47,"hold":5,"sell":0,"strongSell":0},"1":{"period"
#          :"-1m","strongBuy":11,"buy":47,"hold":5,"sell":0,"strongSell":0},"2":{"period":"-2m","stron
#          gBuy":12,"buy":48,"hold":4,"sell":0,"strongSell":0},"3":{"period":"-3m","strongBuy":12,"buy
#          ":48,"hold":4,"sell":0,"strongSell":0}}
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: call_dsp3
# DEBUG    {
#            "symbol": "TSLA",
#            "company_name": "Tesla, Inc.",
#            "sector": "Consumer Cyclical",
#            "industry": "Auto Manufacturers",
#            "market_cap": 872657911808,
#            "pe_ratio": 83.73611,
#            "pb_ratio": 11.966522,
#            "dividend_yield": "N/A",
#            "eps": 2.04,
#            "beta": 2.507,
#            "52_week_high": 488.54,
#            "52_week_low": 138.8
#          }
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: call_x5c2
# DEBUG    {
#            "symbol": "NVDA",
#            "company_name": "NVIDIA Corporation",
#            "sector": "Technology",
#            "industry": "Semiconductors",
#            "market_cap": 2821371723776,
#            "pe_ratio": 28.065535,
#            "pb_ratio": 35.67726,
#            "dividend_yield": 0.03,
#            "eps": 2.93,
#            "beta": 1.765,
#            "52_week_high": 153.13,
#            "52_week_low": 75.606
#          }
# DEBUG    ============== assistant ==============
# DEBUG    ### Analyst Recommendations for TSLA and NVDA
#
#          The following tables summarize the analyst recommendations for TSLA and NVDA:
#
#          #### TSLA Analyst Recommendations
#          | Period | Strong Buy | Buy | Hold | Sell | Strong Sell |
#          | --- | --- | --- | --- | --- | --- |
#          | 0m | 7 | 13 | 15 | 9 | 3 |
#          | -1m | 7 | 13 | 15 | 9 | 3 |
#          | -2m | 7 | 13 | 15 | 8 | 4 |
#          | -3m | 7 | 13 | 15 | 8 | 5 |
#
#          #### NVDA Analyst Recommendations
#          | Period | Strong Buy | Buy | Hold | Sell | Strong Sell |
#          | --- | --- | --- | --- | --- | --- |
#          | 0m | 11 | 47 | 5 | 0 | 0 |
#          | -1m | 11 | 47 | 5 | 0 | 0 |
#          | -2m | 12 | 48 | 4 | 0 | 0 |
#          | -3m | 12 | 48 | 4 | 0 | 0 |
#
#          ### Fundamentals for TSLA and NVDA
#
#          The following tables summarize the fundamentals for TSLA and NVDA:
#
#          #### TSLA Fundamentals
#          | Category | Value |
#          | --- | --- |
#          | Symbol | TSLA |
#          | Company Name | Tesla, Inc. |
#          | Sector | Consumer Cyclical |
#          | Industry | Auto Manufacturers |
#          | Market Cap | 872,657,911,808 |
#          | PE Ratio | 83.74 |
#          | PB Ratio | 11.97 |
#          | Dividend Yield | N/A |
#          | EPS | 2.04 |
#          | Beta | 2.51 |
#          | 52-Week High | 488.54 |
#          | 52-Week Low | 138.8 |
#
#          #### NVDA Fundamentals
#          | Category | Value |
#          | --- | --- |
#          | Symbol | NVDA |
#          | Company Name | NVIDIA Corporation |
#          | Sector | Technology |
#          | Industry | Semiconductors |
#          | Market Cap | 2,821,371,723,776 |
#          | PE Ratio | 28.07 |
#          | PB Ratio | 35.68 |
#          | Dividend Yield | 0.03 |
#          | EPS | 2.93 |
#          | Beta | 1.77 |
#          | 52-Week High | 153.13 |
#          | 52-Week Low | 75.61 |
#
#          ### Comparison of Analyst Recommendations and Fundamentals
#
#          Based on the analyst recommendations, NVDA has a stronger buy signal with 11 strong buys
#          and 47 buys, compared to TSLA's 7 strong buys and 13 buys. NVDA also has a higher market
#          capitalization and a lower PE ratio compared to TSLA. However, TSLA has a higher beta,
#          indicating higher volatility. Ultimately, the decision to invest in either stock depends on
#          individual investment goals and risk tolerance.
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   2.7720s
# DEBUG    * Tokens per second:           227.2721 tokens/s
# DEBUG    * Input tokens:                1022
# DEBUG    * Output tokens:               630
# DEBUG    * Total tokens:                1652
# DEBUG    * Completion time:             2.2909s
# DEBUG    * Prompt time:                 0.0441s
# DEBUG    * Queue time:                  0.2485s
# DEBUG    * Total time:                  2.3350s
# DEBUG    **************** METRICS END ******************
# DEBUG    ---------- Groq Response End ----------
# DEBUG    Added 7 Messages to AgentMemory
# DEBUG    Added AgentRun to AgentMemory
# DEBUG    --**-- Logging Agent Run
# DEBUG    *********** Agent Run End: 187a4a79-d7e9-4eba-afd8-e50d8935b0d8 ***********
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                  ┃
# ┃ summarize and compare analyst recommandations and fundamentals for TESLA and NVDA                ┃
# ┃                                                                                                  ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (5.5s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                  ┃
# ┃ Running:                                                                                         ┃
# ┃                                                                                                  ┃
# ┃  • get_analyst_recommendations(symbol=TSLA)                                                      ┃
# ┃  • get_analyst_recommendations(symbol=NVDA)                                                      ┃
# ┃  • get_stock_fundamentals(symbol=TSLA)                                                           ┃
# ┃  • get_stock_fundamentals(symbol=NVDA)                                                           ┃
# ┃                                                                                                  ┃
# ┃                            Analyst Recommendations for TSLA and NVDA                             ┃
# ┃                                                                                                  ┃
# ┃ The following tables summarize the analyst recommendations for TSLA and NVDA:                    ┃
# ┃                                                                                                  ┃
# ┃                                   TSLA Analyst Recommendations                                   ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃   Period   Strong Buy   Buy   Hold   Sell   Strong Sell                                          ┃
# ┃  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━                                         ┃
# ┃   0m       7            13    15     9      3                                                    ┃
# ┃   -1m      7            13    15     9      3                                                    ┃
# ┃   -2m      7            13    15     8      4                                                    ┃
# ┃   -3m      7            13    15     8      5                                                    ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃                                   NVDA Analyst Recommendations                                   ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃   Period   Strong Buy   Buy   Hold   Sell   Strong Sell                                          ┃
# ┃  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━                                         ┃
# ┃   0m       11           47    5      0      0                                                    ┃
# ┃   -1m      11           47    5      0      0                                                    ┃
# ┃   -2m      12           48    4      0      0                                                    ┃
# ┃   -3m      12           48    4      0      0                                                    ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃                                  Fundamentals for TSLA and NVDA                                  ┃
# ┃                                                                                                  ┃
# ┃ The following tables summarize the fundamentals for TSLA and NVDA:                               ┃
# ┃                                                                                                  ┃
# ┃                                        TSLA Fundamentals                                         ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃   Category         Value                                                                         ┃
# ┃  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━                                                           ┃
# ┃   Symbol           TSLA                                                                          ┃
# ┃   Company Name     Tesla, Inc.                                                                   ┃
# ┃   Sector           Consumer Cyclical                                                             ┃
# ┃   Industry         Auto Manufacturers                                                            ┃
# ┃   Market Cap       872,657,911,808                                                               ┃
# ┃   PE Ratio         83.74                                                                         ┃
# ┃   PB Ratio         11.97                                                                         ┃
# ┃   Dividend Yield   N/A                                                                           ┃
# ┃   EPS              2.04                                                                          ┃
# ┃   Beta             2.51                                                                          ┃
# ┃   52-Week High     488.54                                                                        ┃
# ┃   52-Week Low      138.8                                                                         ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃                                        NVDA Fundamentals                                         ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃   Category         Value                                                                         ┃
# ┃  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━                                                           ┃
# ┃   Symbol           NVDA                                                                          ┃
# ┃   Company Name     NVIDIA Corporation                                                            ┃
# ┃   Sector           Technology                                                                    ┃
# ┃   Industry         Semiconductors                                                                ┃
# ┃   Market Cap       2,821,371,723,776                                                             ┃
# ┃   PE Ratio         28.07                                                                         ┃
# ┃   PB Ratio         35.68                                                                         ┃
# ┃   Dividend Yield   0.03                                                                          ┃
# ┃   EPS              2.93                                                                          ┃
# ┃   Beta             1.77                                                                          ┃
# ┃   52-Week High     153.13                                                                        ┃
# ┃   52-Week Low      75.61                                                                         ┃
# ┃                                                                                                  ┃
# ┃                                                                                                  ┃
# ┃                      Comparison of Analyst Recommendations and Fundamentals                      ┃
# ┃                                                                                                  ┃
# ┃ Based on the analyst recommendations, NVDA has a stronger buy signal with 11 strong buys and 47  ┃
# ┃ buys, compared to TSLA's 7 strong buys and 13 buys. NVDA also has a higher market capitalization ┃
# ┃ and a lower PE ratio compared to TSLA. However, TSLA has a higher beta, indicating higher        ┃
# ┃ volatility. Ultimately, the decision to invest in either stock depends on individual investment  ┃
# ┃ goals and risk tolerance.                                                                        ┃
# ┃                                                                                                  ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
